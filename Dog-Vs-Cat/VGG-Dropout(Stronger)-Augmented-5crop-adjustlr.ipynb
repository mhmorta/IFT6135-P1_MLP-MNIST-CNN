# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torch.nn.functional as F
import torchvision
import torchvision.transforms
import matplotlib.pyplot as plt
import numpy as np
import glob
import pandas as pd
from torch.utils.data import DataLoader
from torchsummary import summary
from IPython.core.debugger import set_trace

from Tools import Trainer

# %% [markdown]
# ## Loading datasets

# %%
from Tools.Dataloader import datasets_loader

normalize = torchvision.transforms.Normalize((0.4895832, 0.4546405, 0.41594946), 
                                (0.2520022, 0.24522494, 0.24728711))
train_val_transforms = torchvision.transforms.Compose([
                            torchvision.transforms.RandomCrop(64),
                            torchvision.transforms.RandomHorizontalFlip(),
                            torchvision.transforms.ToTensor(),
                            normalize])

norm_transforms = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                                normalize])       
                                                  
test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.FiveCrop(64), # this is a list of PIL Images
    torchvision.transforms.Lambda(lambda crops: torch.stack([norm_transforms(crop) for crop in crops])), # returns a 4D tensor
])
                                                  
train_loader, valid_loader, test_loader = datasets_loader(train_val_transforms, test_transforms)

# %% [markdown]
# ## Hyper-parameters

# %%
hyperparams = {'num_epochs': 60,
               'lr0' :0.1, 
               'dropout':0.25,
               'gamma': 0.75,
               'adjust_lr': True,
               'init_weights':True,
               'save_checkpoint': True      
                  }
cuda_available = torch.cuda.is_available()

# %% [markdown]
# ## Creating the model

# %%
from Classifier.VGG import VGG16_Dropout

model = VGG16_Dropout(hyperparams)
if cuda_available:
    model = model.cuda()

optimizer = torch.optim.SGD(model.parameters(), lr=hyperparams['lr0'])
criterion = nn.CrossEntropyLoss()

# %%
summary(model, (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 64, 64]           1,792
#               ReLU-2           [-1, 64, 64, 64]               0
#    GaussianDropout-3           [-1, 64, 64, 64]               0
#             Conv2d-4           [-1, 64, 64, 64]          36,928
#               ReLU-5           [-1, 64, 64, 64]               0
#    GaussianDropout-6           [-1, 64, 64, 64]               0
#          MaxPool2d-7           [-1, 64, 32, 32]               0
#             Conv2d-8          [-1, 128, 32, 32]          73,856
#               ReLU-9          [-1, 128, 32, 32]               0
#   GaussianDropout-10          [-1, 128, 32, 32]               0
#            Conv2d-11          [-1, 128, 32, 32]         147,584
#              ReLU-12          [-1, 128, 32, 32]               0
#         MaxPool2d-13          [-1, 128, 16, 16]               0
#            Conv2d-14          [-1, 256, 16, 16]         295,168
#              ReLU-15          [-1, 256, 16, 16]               0
#   GaussianDropout-16          [-1, 256, 16, 16]               0
#            Conv2d-17          [-1, 256, 16, 16]         590,080
#              ReLU-18          [-1, 256, 16, 16]               0
#            Conv2d-19          [-1, 256, 16, 16]         590,080
#              ReLU-20          [-1, 256, 16, 16]               0
#         MaxPool2d-21            [-1, 256, 8, 8]               0
#   GaussianDropout-22            [-1, 256, 8, 8]               0
#            Conv2d-23            [-1, 512, 8, 8]       1,180,160
#              ReLU-24            [-1, 512, 8, 8]               0
#            Conv2d-25            [-1, 512, 8, 8]       2,359,808
#              ReLU-26            [-1, 512, 8, 8]               0
#   GaussianDropout-27            [-1, 512, 8, 8]               0
#            Conv2d-28            [-1, 512, 8, 8]       2,359,808
#              ReLU-29            [-1, 512, 8, 8]               0
#         MaxPool2d-30            [-1, 512, 4, 4]               0
#            Conv2d-31            [-1, 512, 4, 4]       2,359,808
#              ReLU-32            [-1, 512, 4, 4]               0
#   GaussianDropout-33            [-1, 512, 4, 4]               0
#            Conv2d-34            [-1, 512, 4, 4]       2,359,808
#              ReLU-35            [-1, 512, 4, 4]               0
#   GaussianDropout-36            [-1, 512, 4, 4]               0
#            Conv2d-37            [-1, 512, 4, 4]       2,359,808
#              ReLU-38            [-1, 512, 4, 4]               0
#   GaussianDropout-39            [-1, 512, 4, 4]               0
#         MaxPool2d-40            [-1, 512, 2, 2]               0
#            Linear-41                 [-1, 4096]       8,392,704
#            Linear-42                 [-1, 4096]      16,781,312
#            Linear-43                    [-1, 2]           8,194
# ================================================================
# Total params: 39,896,898
# Trainable params: 39,896,898
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 23.95
# Params size (MB): 152.19
# Estimated Total Size (MB): 176.19
# ----------------------------------------------------------------

# %% [markdown]
# ## Training

# %%
from Tools.Trainer import Trainer

trainer = Trainer(model, optimizer, criterion, train_loader, valid_loader, test_loader, hyperparams)
nll_train, nll_valid, acc_train, acc_valid =  trainer.train_model()
print('Done...')
# Out:
# ------ Epoch # 1 ------
#  Iteration 40: TRAIN 0.6935
#  Iteration 80: TRAIN 0.6938
#  Iteration 120: TRAIN 0.6932
#  [Loss] TRAIN 0.6935 / VALID 0.6938
#  [ACC] TRAIN 0.5002 / VALID 0.4955
# new checkpoint is saved!
# ------ Epoch # 2 ------
#  Iteration 160: TRAIN 0.6933
#  Iteration 200: TRAIN 0.6933
#  Iteration 240: TRAIN 0.6932
#  Iteration 280: TRAIN 0.6933
#  [Loss] TRAIN 0.6929 / VALID 0.6928
#  [ACC] TRAIN 0.5002 / VALID 0.4955
# no improvement!
# ------ Epoch # 3 ------
#  Iteration 320: TRAIN 0.6926
#  Iteration 360: TRAIN 0.6925
#  Iteration 400: TRAIN 0.6913
#  Iteration 440: TRAIN 0.6899
#  [Loss] TRAIN 0.6967 / VALID 0.6941
#  [ACC] TRAIN 0.5049 / VALID 0.5025
# new checkpoint is saved!
# ------ Epoch # 4 ------
#  Iteration 480: TRAIN 0.6883
#  Iteration 520: TRAIN 0.6870
#  Iteration 560: TRAIN 0.6837
#  [Loss] TRAIN 0.6850 / VALID 0.6821
#  [ACC] TRAIN 0.5457 / VALID 0.5636
# new checkpoint is saved!
# ------ Epoch # 5 ------
#  Iteration 600: TRAIN 0.6889
#  Iteration 640: TRAIN 0.6821
#  Iteration 680: TRAIN 0.6904
#  Iteration 720: TRAIN 0.6936
#  [Loss] TRAIN 0.6954 / VALID 0.6947
#  [ACC] TRAIN 0.4998 / VALID 0.5045
# no improvement!
# ------ Epoch # 6 ------
#  Iteration 760: TRAIN 0.6929
#  Iteration 800: TRAIN 0.6925
#  Iteration 840: TRAIN 0.6913
#  Iteration 880: TRAIN 0.6884
#  [Loss] TRAIN 0.6780 / VALID 0.6751
#  [Loss] TRAIN 0.0260 / VALID 0.4048
#  [ACC] TRAIN 0.9909 / VALID 0.8999
# no improvement!
# ------ Epoch # 55 ------
#  Iteration 8080: TRAIN 0.0188
#  Iteration 8120: TRAIN 0.0253
#  Iteration 8160: TRAIN 0.0247
#  [Loss] TRAIN 0.0258 / VALID 0.3504
#  [ACC] TRAIN 0.9925 / VALID 0.9159
# no improvement!
# ------ Epoch # 56 ------
#  Iteration 8200: TRAIN 0.0296
#  Iteration 8240: TRAIN 0.0220
#  Iteration 8280: TRAIN 0.0187
#  Iteration 8320: TRAIN 0.0169
#  [Loss] TRAIN 0.0186 / VALID 0.4217
#  [ACC] TRAIN 0.9929 / VALID 0.9089
# no improvement!
# ------ Epoch # 57 ------
#  Iteration 8360: TRAIN 0.0269
#  Iteration 8400: TRAIN 0.0272
#  Iteration 8440: TRAIN 0.0242
#  Iteration 8480: TRAIN 0.0261
#  [Loss] TRAIN 0.0259 / VALID 0.3688
#  [ACC] TRAIN 0.9901 / VALID 0.9029
# no improvement!
# ------ Epoch # 58 ------
#  Iteration 8520: TRAIN 0.0244
#  Iteration 8560: TRAIN 0.0247
#  Iteration 8600: TRAIN 0.0197
#  Iteration 8640: TRAIN 0.0217
#  [Loss] TRAIN 0.0146 / VALID 0.3199
#  [ACC] TRAIN 0.9945 / VALID 0.9219
# new checkpoint is saved!
# ------ Epoch # 59 ------
#  Iteration 8680: TRAIN 0.0165
#  Iteration 8720: TRAIN 0.0226
#  Iteration 8760: TRAIN 0.0258
#  [Loss] TRAIN 0.0167 / VALID 0.3528
#  [ACC] TRAIN 0.9945 / VALID 0.9089
# no improvement!
# ------ Epoch # 60 ------
#  Iteration 8800: TRAIN 0.0230
#  Iteration 8840: TRAIN 0.0194
#  Iteration 8880: TRAIN 0.0218
#  Iteration 8920: TRAIN 0.0211
#  [Loss] TRAIN 0.0579 / VALID 0.4257
#  [ACC] TRAIN 0.9787 / VALID 0.8899
# no improvement!
# Done...

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### accuracy and loss plots

# %%
import Tools.Visualization as V
V.plots(nll_train, nll_valid, acc_train, acc_valid)

# %%
print(len(nll_train))
# Out:
# 60

# %%
import torchviz
from torch.autograd import Variable
def draw_computational_graph(model):
    x = Variable(torch.randn(1,3,64,64))
    if torch.cuda.is_available():
        x = x.cuda()
    y = model(x)
    img = torchviz.make_dot(y.mean(), params=dict(model.named_parameters()))
    img.format = 'png'
    img.render()
    print('Done...')

# %%
draw_computational_graph(model)
# Out:
# Done...

# %% [markdown]
# ### Confusion Matrix

# %%
import Tools.Visualization as V
cnf_matrix = trainer.confusion_matrix()
V.plot_confusion_matrix(cnf_matrix)

# %% [markdown]
# ## Saving the model

# %%
torch.save(model, "./Experiments/VGG-Dropout(Strong)-Augmented-5crop-adjustlr")

# %% [markdown]
# ## Generate Submission

# %%
import Tools.Trainer as T
results = T.predict_test_set_5crop(model, test_loader)
# print(results.size())
T.generate_submission(results)
# Out:
# Done...
